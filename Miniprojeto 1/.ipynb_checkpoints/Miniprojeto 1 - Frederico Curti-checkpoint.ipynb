# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
from scipy.stats import norm

# %%
pokemon = pd.read_excel("pokemondb.xls")

# %%
pokemon.columns = pokemon.columns.str.replace('POKEMON ','POKEMON')
pokemon = pokemon[pokemon.POKEMON.notnull()]
pokemon = pokemon[pokemon.FORM != "Mega"][pokemon.FORM != "Mega X"][pokemon.FORM != "Mega Y"]
# Out:
# /Users/fredcurti/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()

# %%
pokemon.columns = pokemon.columns.str.replace('BASE STATS','HP')
pokemon.columns = pokemon.columns.str.replace('Unnamed: 13','ATK')
pokemon.columns = pokemon.columns.str.replace('Unnamed: 14','DEF')
pokemon.columns = pokemon.columns.str.replace('Unnamed: 15','SP.ATK')
pokemon.columns = pokemon.columns.str.replace('Unnamed: 16','SP.DEF')
pokemon.columns = pokemon.columns.str.replace('Unnamed: 17','SPEED')
pokemon.columns = pokemon.columns.str.replace('Unnamed: 18','TOTAL')
pokemon.columns = pokemon.columns.str.replace('Unnamed: 11','TOTAL')

# %%
pokemon.drop(pokemon.columns[[9,10,11]], axis=1, inplace=True)

# %%
pokemon2 = pokemon.iloc[:,2:17]
pokemon = pokemon2

# %%
pokemon.HP.plot.hist(bins=22,normed=True,grid=True,figsize=(15,8),color="r")

# %%
pokemon
# Out:
#         POKEMON   FORM    TYPE 1  TYPE 2    ABILITIES 1   ABILITIES 2  \
# 1     Bulbasaur  -----     Grass  Poison       Overgrow         -----
# 2       Ivysaur  -----     Grass  Poison       Overgrow         -----
# 3      Venusaur  -----     Grass  Poison       Overgrow         -----
# 5    Charmander  -----      Fire   -----          Blaze         -----
# 6    Charmeleon  -----      Fire   -----          Blaze         -----
# 7     Charizard  -----      Fire  Flying          Blaze         -----
# 10     Squirtle  -----     Water   -----        Torrent         -----
# 11    Wartortle  -----     Water   -----        Torrent         -----
# 12    Blastoise  -----     Water   -----        Torrent         -----
# 14     Caterpie  -----       Bug   -----    Shield Dust         -----
# 15      Metapod  -----       Bug   -----      Shed Skin         -----
# 16   Butterfree  -----       Bug  Flying   Compoundeyes         -----
# 17       Weedle  -----       Bug  Poison    Shield Dust         -----
# 18       Kakuna  -----       Bug  Poison      Shed Skin         -----
# 19     Beedrill  -----       Bug  Poison          Swarm         -----
# 21       Pidgey  -----    Normal  Flying       Keen Eye  Tangled Feet
# 22    Pidgeotto  -----    Normal  Flying       Keen Eye  Tangled Feet
# 23      Pidgeot  -----    Normal  Flying       Keen Eye  Tangled Feet
# 25      Rattata  -----    Normal   -----       Run Away          Guts
# 26     Raticate  -----    Normal   -----       Run Away          Guts
# 27      Spearow  -----    Normal  Flying       Keen Eye         -----
# 28       Fearow  -----    Normal  Flying       Keen Eye         -----
# 29        Ekans  -----    Poison   -----     Intimidate     Shed Skin
# 30        Arbok  -----    Poison   -----     Intimidate     Shed Skin
# 31        Pichu  -----  Electric   -----         Static         -----
# 32      Pikachu  -----  Electric   -----         Static         -----
# 33       Raichu  -----  Electric   -----         Static         -----
# 34    Sandshrew  -----    Ground   -----      Sand Veil         -----
# 35    Sandslash  -----    Ground   -----      Sand Veil         -----
# 36     Nidoran♀  -----    Poison   -----   Poison Point       Rivalry
# ..          ...    ...       ...     ...            ...           ...
# 781    Dragalge  -----    Poison  Dragon   Poison Point  Poison Touch
# 782   Clauncher  -----     Water   -----  Mega Launcher         -----
# 783   Clawitzer  -----     Water   -----  Mega Launcher         -----
# 784  Helioptile  -----  Electric  Normal      Dry Skin      Sand Veil
# 785   Heliolisk  -----  Electric  Normal      Dry Skin      Sand Veil
# 786      Tyrunt  -----      Rock  Dragon     Strong Jaw         -----
# ..             ...  ...  ...  ...    ...    ...   ...           ...
# 781   Adaptability   65   75   90     97    123    44           YES
# 782          -----   50   53   62     58     63    44           YES
# 783          -----   71   73   88    120     89    59           YES
# 784    Solar Power   44   38   33     61     43    70           YES
# 785    Solar Power   62   55   52    109     94   109           YES
# 786         Sturdy   58   89   77     45     45    48           YES
# 787      Rock Head   82  121  119     69     59    71           YES
# 788   Snow Warning   77   59   50     67     63    46           YES
# 789   Snow Warning  123   77   72     99     92    58           YES
# 790   Mold Breaker   78   92   75     74     63   118           YES
# 791           Plus   67   58   57     81     67   101           YES
# 792         Sturdy   50   50  150     50    150    50           YES
# 793          Gooey   45   50   35     55     75    40           YES
# 794          Gooey   68   75   53     83    113    60           YES
# 795          Gooey   90  100   70    110    150    80           YES
# 796       Magician   57   80   91     80     87    75           YES
# 797        Harvest   43   70   48     50     60    38           YES
# 798        Harvest   85  110   76     65     82    56           YES
# 799       Insomnia   44   66   70     44     55    56           YES
# 803       Insomnia   55   85  122     58     75    99           YES
# 807         Sturdy   55   69   85     32     35    28           YES
# 808         Sturdy   95  117  184     44     46    28           YES
# 809      Telepathy   40   30   35     45     40    55           YES
# 810      Telepathy   85   70   80     97     80   123           YES
# 811          -----  126  131   95    131     98    99           YES
# 812          -----  126  131   95    131     98    99           YES
# 813          -----  108  100  121     81     95    95           YES
# 814          -----   50  100  150    100    150    50           YES
# 816          -----   80  110   60    150    130    70            NO
# 817          -----   80  110  120    130     90    70            NO
#
#     Unnamed: 20
# 1            NO
# 2            NO
# 3            NO
# 5            NO
# 6            NO
# 7            NO
# 10           NO
# 11           NO
# 12           NO
# 14           NO
# 15           NO
# 16           NO
# 17           NO
# 18           NO
# 19           NO
# 21          YES
# 22          YES
# 23          YES
# 25          YES
# 26          YES
# 27           NO
# 28           NO
# 29           NO
# 30           NO
# 31          YES
# 32          YES
# 33          YES
# 34          YES
# 35          YES
# 36           NO
# ..          ...
# 781         YES
# 782         YES
# 783         YES
# 784          NO
# 785          NO
# 786          NO
# 787          NO
# 788          NO
# 789          NO
# 790          NO
# 791          NO
# 792          NO
# 793          NO
# 794          NO
# 795          NO
# 796         YES
# 797         YES
# 798         YES
# 799          NO
# 803          NO
# 807          NO
# 808          NO
# 809          NO
# 810          NO
# 811          NO
# 812          NO
# 813          NO
# 814          NO
# 816          NO
# 817          NO
#
# [723 rows x 15 columns]

# %%
pokemonnorm = norm.rvs(loc=0, scale=1, size=2000)

# %%
mean = pokemon.HP.mean()
std = pokemon.HP.std()

# %%
pokemon.HP.plot.hist(bins=25,normed=True,grid=True,figsize=(15,8),color="red")
x = np.linspace(0, pokemon.HP.max(), 1000)
y = norm.pdf(x, loc=mean, scale=std)
plt.plot(x,y)

# %%
print("A tabela possui",pokemon.shape[0], "pokémons" )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-da46475d91f5> in <module>()
# ----> 1 print("A tabela possui",pokemon.shape[0], "pokémons" )
#
# NameError: name 'pokemon' is not defined

# %% [markdown]
# **Eu escolhi as curvas de adequação normal e exponencial decrescente, pois eu acredito que a maioria dos pokemóns possa ter um hp médio em relação aos extremos, ou existem muitos com HP baixo e isso vai diminuindo exponencialmente, com poucos pokemons de hp alto.**

# %%
pokemon.HP.max()
# Out:
# 255
